# %%
from random import shuffle
def get_topk(file_name, k):
    
    res = []
#     stop = 10000
    
#     line_count = 0
    f = open(file_name)
    for line in f.readlines():
        componemts = line.strip().split(',')
        res.append(int(componemts[0]))
#         line_count += 1
#         if line_count == stop:
#             break
    f.close()
    shuffle(res)
    return res[:k]

# %%
def reidx(ori_list):
    i = 1
    res = {}
    for a in ori_list:
        res[a] = i;
        i += 1
    return res

# %%
user_num = 3000
item_num = 3000

user_file = 'netflix_user.txt'
item_file = 'netflix_item.txt'


user = get_topk(user_file,user_num)
item = get_topk(item_file,item_num)

user_idx = reidx(user)
item_idx = reidx(item)

# %%
import os
folder = 'raw_data/nf_prize_dataset.tar/download/download/training_set'

output = 'netflix_subset.csv'

f_write = open(output,'wb')

for root, dirs, files in os.walk(folder):
    
    for movie_file_name in files:
        
        movie_id = int(movie_file_name.split('_')[1].split('.')[0])
        if movie_id%100==0:
            print 'processing file: %s' % movie_file_name 
        
        if movie_id not in item_idx:
            continue
        
        movie_file = open(os.path.join(root,movie_file_name))
        
        # skip the sign
        movie_file.readline()
        
        for line in movie_file.readlines():
#             print line
            components = line.strip().split(',')
            user_id = int(components[0])
            if user_id not in user_idx:
                continue
            rating = components[1]
            f_write.write(str(user_idx[user_id]) + ',' + str(item_idx[movie_id]) + ',' + rating + '\n')
        movie_file.close()

f_write.close()
# Out:
# processing file: mv_0000100.txt
# processing file: mv_0000200.txt
# processing file: mv_0000300.txt
# processing file: mv_0000400.txt
# processing file: mv_0000500.txt
# processing file: mv_0000600.txt
# processing file: mv_0000700.txt
# processing file: mv_0000800.txt
# processing file: mv_0000900.txt
# processing file: mv_0001000.txt
# processing file: mv_0001100.txt
# processing file: mv_0001200.txt
# processing file: mv_0001300.txt
# processing file: mv_0001400.txt
# processing file: mv_0001500.txt
# processing file: mv_0001600.txt
# processing file: mv_0001700.txt
# processing file: mv_0001800.txt
# processing file: mv_0001900.txt
# processing file: mv_0002000.txt
# processing file: mv_0002100.txt
# processing file: mv_0002200.txt
# processing file: mv_0002300.txt
# processing file: mv_0002400.txt
# processing file: mv_0002500.txt
# processing file: mv_0002600.txt
# processing file: mv_0002700.txt
# processing file: mv_0002800.txt
# processing file: mv_0002900.txt
# processing file: mv_0003000.txt
# processing file: mv_0003100.txt
# processing file: mv_0003200.txt
# processing file: mv_0003300.txt
# processing file: mv_0003400.txt
# processing file: mv_0003500.txt
# processing file: mv_0003600.txt
# processing file: mv_0003700.txt
# processing file: mv_0003800.txt
# processing file: mv_0003900.txt
# processing file: mv_0004000.txt
# processing file: mv_0004100.txt
# processing file: mv_0004200.txt
# processing file: mv_0004300.txt
# processing file: mv_0004400.txt
# processing file: mv_0004500.txt
# processing file: mv_0004600.txt
# processing file: mv_0004700.txt
# processing file: mv_0004800.txt
# processing file: mv_0004900.txt
# processing file: mv_0005000.txt
# processing file: mv_0005100.txt
# processing file: mv_0005200.txt
# processing file: mv_0005300.txt
# processing file: mv_0005400.txt
# processing file: mv_0005500.txt
# processing file: mv_0005600.txt
# processing file: mv_0005700.txt
# processing file: mv_0005800.txt
# processing file: mv_0005900.txt
# processing file: mv_0006000.txt
# processing file: mv_0006100.txt
# processing file: mv_0006200.txt
# processing file: mv_0006300.txt
# processing file: mv_0006400.txt
# processing file: mv_0006500.txt
# processing file: mv_0006600.txt
# processing file: mv_0006700.txt
# processing file: mv_0006800.txt
# processing file: mv_0006900.txt
# processing file: mv_0007000.txt
# processing file: mv_0007100.txt
# processing file: mv_0007200.txt
# processing file: mv_0007300.txt
# processing file: mv_0007400.txt
# processing file: mv_0007500.txt
# processing file: mv_0007600.txt
# processing file: mv_0007700.txt
# processing file: mv_0007800.txt
# processing file: mv_0007900.txt
# processing file: mv_0008000.txt
# processing file: mv_0008100.txt
# processing file: mv_0008200.txt
# processing file: mv_0008300.txt
# processing file: mv_0008400.txt
# processing file: mv_0008500.txt
# processing file: mv_0008600.txt
# processing file: mv_0008700.txt
# processing file: mv_0008800.txt
# processing file: mv_0008900.txt
# processing file: mv_0009000.txt
# processing file: mv_0009100.txt
# processing file: mv_0009200.txt
# processing file: mv_0009300.txt
# processing file: mv_0009400.txt
# processing file: mv_0009500.txt
# processing file: mv_0009600.txt
# processing file: mv_0009700.txt
# processing file: mv_0009800.txt
# processing file: mv_0009900.txt
# processing file: mv_0010000.txt
# processing file: mv_0010100.txt
# processing file: mv_0010200.txt
# processing file: mv_0010300.txt
# processing file: mv_0010400.txt
# processing file: mv_0010500.txt
# processing file: mv_0010600.txt
# processing file: mv_0010700.txt
# processing file: mv_0010800.txt
# processing file: mv_0010900.txt
# processing file: mv_0011000.txt
# processing file: mv_0011100.txt
# processing file: mv_0011200.txt
# processing file: mv_0011300.txt
# processing file: mv_0011400.txt
# processing file: mv_0011500.txt
# processing file: mv_0011600.txt
# processing file: mv_0011700.txt
# processing file: mv_0011800.txt
# processing file: mv_0011900.txt
# processing file: mv_0012000.txt
# processing file: mv_0012100.txt
# processing file: mv_0012200.txt
# processing file: mv_0012300.txt
# processing file: mv_0012400.txt
# processing file: mv_0012500.txt
# processing file: mv_0012600.txt
# processing file: mv_0012700.txt
# processing file: mv_0012800.txt
# processing file: mv_0012900.txt
# processing file: mv_0013000.txt
# processing file: mv_0013100.txt
# processing file: mv_0013200.txt
# processing file: mv_0013300.txt
# processing file: mv_0013400.txt
# processing file: mv_0013500.txt
# processing file: mv_0013600.txt
# processing file: mv_0013700.txt
# processing file: mv_0013800.txt
# processing file: mv_0013900.txt
# processing file: mv_0014000.txt
# processing file: mv_0014100.txt
# processing file: mv_0014200.txt
# processing file: mv_0014300.txt
# processing file: mv_0014400.txt
# processing file: mv_0014500.txt
# processing file: mv_0014600.txt
# processing file: mv_0014700.txt
# processing file: mv_0014800.txt
# processing file: mv_0014900.txt
# processing file: mv_0015000.txt
# processing file: mv_0015100.txt
# processing file: mv_0015200.txt
# processing file: mv_0015300.txt
# processing file: mv_0015400.txt
# processing file: mv_0015500.txt
# processing file: mv_0015600.txt
# processing file: mv_0015700.txt
# processing file: mv_0015800.txt
# processing file: mv_0015900.txt
# processing file: mv_0016000.txt
# processing file: mv_0016100.txt
# processing file: mv_0016200.txt
# processing file: mv_0016300.txt
# processing file: mv_0016400.txt
# processing file: mv_0016500.txt
# processing file: mv_0016600.txt
# processing file: mv_0016700.txt
# processing file: mv_0016800.txt
# processing file: mv_0016900.txt
# processing file: mv_0017000.txt
# processing file: mv_0017100.txt
# processing file: mv_0017200.txt
# processing file: mv_0017300.txt
# processing file: mv_0017400.txt
# processing file: mv_0017500.txt
# processing file: mv_0017600.txt
# processing file: mv_0017700.txt

# %%
a = [x for x in xrange(10)]
shuffle(a)
a
# Out:
# [4, 1, 3, 2, 5, 9, 7, 6, 8, 0]
